# %% [markdown]
# <img src="Assets/yahoo_finance_logo.png" alt="drawing" width="200" />
#
# <h1 style="text-align: center;">stock-market-scraper</h1>

# %% [markdown]
# <br/>
# <br/>
#
# ### `Remember this is for downloading only selected stocks only. `
# * **`For mass downloading, head here:`  [stock-market-scraper](https://github.com/Gunjan933/stock-market-scraper/blob/master/stock-market-scraper.py)**
#
# * **`Readme is here:`  [README.md](https://github.com/Gunjan933/stock-market-scraper/blob/master/README.md)**
#
#
#
# <br/>
# <br/>
#
# # Let's see the scraping idea
# <br/>
#
# **Yahoo has gone to a Reactjs front end which means if you analyze the request headers from the client to the backend you can get the actual JSON they use to populate the client side stores.**
#
#
#
#
#
#
# <br/>
#
# ### Hosts:
# * `query1.finance.yahoo.com` HTTP/1.0
# * `query2.finance.yahoo.com` HTTP/1.1 [difference between HTTP/1.0 & HTTP/1.1](https://stackoverflow.com/questions/246859/http-1-0-vs-1-1)
#
# If you plan to use a proxy or persistent connections use `query2.finance.yahoo.com`. But for the purposes of this post the host used for the example URLs is not meant to imply anything about the path it's being used with.
#
# > We will use HTTP/1.1
#
#
# ### Fundamental Data
# * `/v10/finance/quoteSummary/AAPL?modules=` (Full list of modules below)
#
# (substitute your symbol for: AAPL)
#
# #### Inputs for the `?modules=` query:
#
# * ```modules = [
#    'assetProfile',
#    'incomeStatementHistory',
#    'incomeStatementHistoryQuarterly',
#    'balanceSheetHistory',
#    'balanceSheetHistoryQuarterly',
#    'cashflowStatementHistory',
#    'cashflowStatementHistoryQuarterly',
#    'defaultKeyStatistics',
#    'financialData',
#    'calendarEvents',
#    'secFilings',
#    'recommendationTrend',
#    'upgradeDowngradeHistory',
#    'institutionOwnership',
#    'fundOwnership',
#    'majorDirectHolders',
#    'majorHoldersBreakdown',
#    'insiderTransactions',
#    'insiderHolders',
#    'netSharePurchaseActivity',
#    'earnings',
#    'earningsHistory',
#    'earningsTrend',
#    'industryTrend',
#    'indexTrend',
#    'sectorTrend' ]
#    ```
# #### Example URL:
#
# * `https://query1.finance.yahoo.com/v10/finance/quoteSummary/AAPL?modules=assetProfile%2CearningsHistory`
#
# Querying for: `assetProfile` and `earningsHistory`
#
# The `%2C` is the Hex representation of `,` and needs to be inserted between each module you request. [details about the hex encoding bit](https://stackoverflow.com/questions/6182356/what-is-2c-in-a-url) (if you care)
#
# <br/>
#
# ### Options contracts
# * `/v7/finance/options/AAPL` (current expiration)
# * `/v7/finance/options/AAPL?date=1579219200` (January 17, 2020 expiration)
#
# #### Example URL:
#
# * `https://query2.finance.yahoo.com/v7/finance/options/AAPL` (current expiration)
# * `https://query2.finance.yahoo.com/v7/finance/options/AAPL?date=1579219200` (January 17, 2020 expiration)
#
# Any valid future expiration represented as a UNIX timestamp can be used in the `?date=` query. If you query for the current expiration the JSON response will contain a list of all the valid expirations that can be used in the `?date=` query. ([here is a post explaining converting human readable dates to unix timestamp in Python](https://stackoverflow.com/questions/3682748/converting-unix-timestamp-string-to-readable-date))
#
# <br/>
#
# ### Price
# * `/v8/finance/chart/AAPL?symbol=AAPL&period1=0&period2=9999999999&interval=3mo`
#
# #### Intervals:
#
# * `&interval=3mo` 3 months, going back until initial trading date.
# * `&interval=1d` 1 day, going back until initial trading date.
# * `&interval=5m` 5 minuets, going back 80(ish) days.
# * `&interval=1m` 1 minuet, going back 4-5 days.
#
# How far back you can go with each interval is a little confusing and seems inconsistent. My assumption is that internally yahoo is counting in trading days and my naive approach was not accounting for holidays. Although that's a guess and YMMV.
#
# `period1=`: unix timestamp representation of the date you wish to **start** at. Values below the initial trading date will be rounded up to the initial trading date.
#
# `period2=`: unix timestamp representation of the date you wish to **end** at. Values greater than the last trading date will be rounded down to the most recent timestamp available.
#
# **Note:** *If you query with a `period1=` (start date) that is too far in the past for the interval you've chosen, yahoo will return prices in the `3mo` interval regardless of what interval you requested.*
#
# #### Add pre & post market data
#
# `&includePrePost=true`
#
# #### Add dividends & splits
#
# `&events=div%2Csplit`
#
# #### Example URL:
#
# * `https://query1.finance.yahoo.com/v8/finance/chart/AAPL?symbol=AAPL&period1=0&period2=9999999999&interval=1d&includePrePost=true&events=div%2Csplit`
#
# The above request will return all price data for ticker AAPL on a 1 day interval including pre and post market data as well as dividends and splits.
#
# **Note:** *the values used in the price example url for `period1=` & `period2=` are to demonstrate the respective rounding behavior of each input.*

# %% [markdown]
# <br/>
#
# `The above article is taken from `**[here](https://stackoverflow.com/a/47505102/8141330)**`.`
#
# <br/>

# %% [markdown]
# ### Dividents and Splits
#
# Yahoo adjusts **all historical** prices to reflect a stock **split**. For example, `ISRG` was trading around $1000 prior to `2017/10/06`. Then on `2017/10/06`, it underwent a 3-for-1 stock split. As you can see, Yahoo's historical prices divided all prices by 3 (both prior to and after `2017/10/06`):
#
#
# ![](Assets/splits.png)
#
# For **dividends**, let's say stock `ABC` closed at 200 on December 18. Then on December 19, the stock increases in price by `$2` but it pays out a `$1` dividend. In Yahoo's historical prices for XYZ, you will see that it closed at 200 on Dec 18 and 201 on Dec 19. Yahoo factors in the dividend in the **"Adj Close"** column for all the previous days. So the Close for Dec 18 would be 200, but the Adj Close would be 199.
#
# For example, on 2017/09/15, SPY paid out a `$1.235` dividend. Yahoo's historical prices say that SPY's closing price on 2017/09/14 was 250.09, but the Adj Close is 248.85, which is `$1.24` lower. The **Adjusted Close** for the previous days was reduced by the dividend amount.
#
# ![](Assets/dividents.png)

# %% [markdown]
# <br/>
#
# `The above article is taken from `**[here](https://money.stackexchange.com/a/44146)**`.`
#
# <br/>

# %% [markdown]
# <br/>
#
# # Now let's get back to some Code to get historic prices of stocks
# <br/>

# %% [markdown]
# #### Import some modules:
# * **urllib**: *To get url data*
# * **json**: *To handle json files*
# * **time**: *To put the program in sleep for some time*
# * **os**: *To walk through different directories*
# * **difflib**: *To get close matches of strings. Helps to find correct stock from the input user gives.*
# * **itertools**: *To repeat same variable to pass in multithreading funciton.*
# * **pandas**: *To handle matrix and csv file*
# * **datetime**: *To change unix timestamp to normal date and time. Yahoo query uses unix timestamp*

# %%
import urllib.request, json , time, os, difflib, itertools
import pandas as pd
from multiprocessing.dummy import Pool
from datetime import datetime
from os import listdir

# %% [markdown]
# #### Let's make a code snippet which can tell if we have working internet connection or not.
# <br/>

# %%
try:
    import httplib
except:
    import http.client as httplib

def check_internet():
    conn = httplib.HTTPConnection("www.google.com", timeout=5)
    try:
        conn.request("HEAD", "/")
        conn.close()
        # print("True")
        return True
    except:
        conn.close()
        # print("False")
        return False

# %% [markdown]
# <br/>
#
# Now see below, I have opened an arbitrary stock `Igarashi Motors`. In URL can you see the **ticker** for the stock? It is `IGARASHI.BO`
#
# <br/>
#
# ![](Assets/chart.png)
#
#
# <br/>
# <br/>
# <br/>
#
# How to get the **ticker**, I will show you later.
#
# First let us make a **function** that can pull `json data` from yahoo about that stock like below. (I will discuss about the function `parameters` later)
# > We will be using query2
#
# <br/>
# <br/>
# <br/>
#
# ![](Assets/query_json.png)
#
# <br/>
# <br/>

# %% [markdown]
# <br/>
#
# ### Now write down the function which will `get_stock_price` for given `query_url`.
#
# #### It will save the stock data as `json` and `csv` inside a folder named "historic_data"
# <br/>

# %%
def get_historic_price(query_url,json_path,csv_path):
    
    while not check_internet():
        print("Could not connect, trying again in 5 seconds...")
        time.sleep(5)
    
    stock_id=query_url.split("&period")[0].split("symbol=")[1]
    
    if os.path.exists(csv_path+stock_id+'.csv') and os.stat(csv_path+stock_id+'.csv').st_size != 0:
        print("<<<  Historical data of "+stock_id+" already exists, Updating data...")

    try:
        with urllib.request.urlopen(query_url) as url:
            parsed = json.loads(url.read().decode())
    except:
        print("|||  Historical data of "+stock_id+" doesn't exist")
        return
    
    else:
        if os.path.exists(json_path+stock_id+'.json'):
            os.remove(json_path+stock_id+'.json')
        with open(json_path+stock_id+'.json', 'w') as outfile:
            json.dump(parsed, outfile, indent=4)

        try:
            Date=[]
            for i in parsed['chart']['result'][0]['timestamp']:
                Date.append(datetime.utcfromtimestamp(int(i)).strftime('%d-%m-%Y'))

            Low=parsed['chart']['result'][0]['indicators']['quote'][0]['low']
            Open=parsed['chart']['result'][0]['indicators']['quote'][0]['open']
            Volume=parsed['chart']['result'][0]['indicators']['quote'][0]['volume']
            High=parsed['chart']['result'][0]['indicators']['quote'][0]['high']
            Close=parsed['chart']['result'][0]['indicators']['quote'][0]['close']
            Adjusted_Close=parsed['chart']['result'][0]['indicators']['adjclose'][0]['adjclose']

            df=pd.DataFrame(list(zip(Date,Low,Open,Volume,High,Close,Adjusted_Close)),columns =['Date','Low','Open','Volume','High','Close','Adjusted Close'])

            if os.path.exists(csv_path+stock_id+'.csv'):
                os.remove(csv_path+stock_id+'.csv')
            df.to_csv(csv_path+stock_id+'.csv', sep=',', index=None)
            print(">>>  Historical data of "+stock_id+" saved")
            return
        except:
            print(">>>  Historical data of "+stock_id+" exists but has no trading data")

# %% [markdown]
# <br/>
#
# #### First we have to set where the `json` and `csv` files will be saved which have been passed to the function `get_historic_price()`
# <br/>

# %%
json_path = os.getcwd()+os.sep+".."+os.sep+"historic_data"+os.sep+"json"+os.sep
csv_path = os.getcwd()+os.sep+".."+os.sep+"historic_data"+os.sep+"csv"+os.sep

# %% [markdown]
#
# #### Then we have to check if these directory exists, if not, then we will use `os.mkdir`

# %%
if not os.path.isdir(json_path):
    os.makedirs(json_path)
if not os.path.isdir(csv_path):
    os.makedirs(csv_path)

# %% [markdown]
# <br/>
# <br/>
#
# ## Getting tickers
#
# Now as promised I will be showing how to find **historical data**. See below, I have opened historical data of `Igarashi Motors`. Here you can see max time period from which we can pull data for the stock. It stores period as `unix timestamp` in the query.
#
# <br/>
#
# ![](Assets/historic_data.png)
#
#
# <br/>
# <br/>
# <br/>
#
# Now let's make the **query**. First set
# * `period1 = 0`
# * `period2 = 9999999999`
# * `interval = 1d`
#
# See the image below, it's `period1` is greater than `0` and `period2` is lesser than `9999999999`. This produces maximum span period from which data can be pulled.
#
# <br/>
# <br/>
# <br/>
#
# ![](Assets/find_query.png)
#
# <br/>
# <br/>

# %% [markdown]
# <br/>
#
# #### Then we need to open our csv file where `yahoo finance tickers` are saved. This is in the `Assets` folder
# <br/>
#
# How did I get this? Well here is the **[direct link](http://investexcel.net/wp-content/uploads/2015/01/Yahoo-Ticker-Symbols-September-2017.zip)** to download the **yahoo ticker list (last updated September 2017)**. It would be helpful for the author if you visit **[his website page](http://investexcel.net/all-yahoo-finance-stock-tickers/)**, as his income is through advertisements, and it takes lots of hours to create this type of ticker list.
#
# All right, moving on.
#
# <br/>
#
# ## Important Note:
#
# As I will be working on `India`, I will be using a function which gives me the list of stocks which are from India only. If you are from any other country, just change the `country name`, and it will return a list of stocks that are only of `your country`. This shrinking will help us speed up the program. As the original list contains **`106328 stocks`**.

# %%
country_name = "USA"

# %% [markdown]
# #### Let's now make the funciton to shrink the ticker list.

# %%
ticker_file_path = "Assets"+os.sep+"Yahoo Ticker Symbols - September 2017.xlsx"
temp_df = pd.read_excel(ticker_file_path)
print("Total stocks:",len(temp_df))
temp_df.head(10)
# Out:
# Total stocks: 106331
#       Yahoo Stock Tickers                               Unnamed: 1 Unnamed: 2
# 0  http://investexcel.net                                      NaN        NaN  \
# 1                     NaN                                      NaN        NaN
# 2                  Ticker                                     Name   Exchange
# 3                    OEDV  Osage Exploration and Development, Inc.        PNK
# 4                    AAPL                               Apple Inc.        NMS
# 5                     BAC              Bank of America Corporation        NYQ
# 6                    AMZN                         Amazon.com, Inc.        NMS
# 7                       T                                AT&T Inc.        NYQ
# 8                    GOOG                            Alphabet Inc.        NMS
# 9                      MO                       Altria Group, Inc.        NYQ
#
#                        Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0                             NaN        NaN         NaN         NaN  \
# 1                             NaN        NaN         NaN         NaN
# 2                   Category Name    Country         NaN         NaN
# 3                             NaN        USA         NaN         NaN
# 4            Electronic Equipment        USA         NaN         NaN
# 5              Money Center Banks        USA         NaN         NaN
# 6     Catalog & Mail Order Houses        USA         NaN         NaN
# 7     Telecom Services - Domestic        USA         NaN         NaN
# 8  Internet Information Providers        USA         NaN         NaN
# 9                      Cigarettes        USA         NaN         NaN
#
#                                           Unnamed: 7
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                         Samir Khan
# 4                     simulationconsultant@gmail.com
# 5                                                NaN
# 6        This ticker symbol list was downloaded from
# 7  http://investexcel.net/all-yahoo-finance-stock...
# 8              and was updated on 2nd September 2017
# 9                                                NaN

# %% [markdown]
# <br/>
#
# #### See the above list is messy, it contains garbage informations. So refining it we get
# <br/>

# %%
temp_df = temp_df.drop(temp_df.columns[[5, 6, 7]], axis=1)
headers = temp_df.iloc[2]
df  = pd.DataFrame(temp_df.values[3:], columns=headers)
print("Total stocks:",len(df))
df.head(10)
# Out:
# Total stocks: 106328
# 2 Ticker                                     Name Exchange
# 0   OEDV  Osage Exploration and Development, Inc.      PNK  \
# 1   AAPL                               Apple Inc.      NMS
# 2    BAC              Bank of America Corporation      NYQ
# 3   AMZN                         Amazon.com, Inc.      NMS
# 4      T                                AT&T Inc.      NYQ
# 5   GOOG                            Alphabet Inc.      NMS
# 6     MO                       Altria Group, Inc.      NYQ
# 7    DAL                    Delta Air Lines, Inc.      NYQ
# 8     AA                        Alcoa Corporation      NYQ
# 9    AXP                 American Express Company      NYQ
#
# 2                   Category Name Country
# 0                             NaN     USA
# 1            Electronic Equipment     USA
# 2              Money Center Banks     USA
# 3     Catalog & Mail Order Houses     USA
# 4     Telecom Services - Domestic     USA
# 5  Internet Information Providers     USA
# 6                      Cigarettes     USA
# 7                  Major Airlines     USA
# 8                        Aluminum     USA
# 9                 Credit Services     USA

# %% [markdown]
# <br/>
#
# #### Let's only take the country which is set to `country_name` previously
# <br/>

# %%
new_df = df[df["Country"].str.lower().str.contains(country_name.lower()) == True]
print("Total stocks:",len(new_df))
new_df.head(10)
# Out:
# Total stocks: 22169
# 2 Ticker                                     Name Exchange
# 0   OEDV  Osage Exploration and Development, Inc.      PNK  \
# 1   AAPL                               Apple Inc.      NMS
# 2    BAC              Bank of America Corporation      NYQ
# 3   AMZN                         Amazon.com, Inc.      NMS
# 4      T                                AT&T Inc.      NYQ
# 5   GOOG                            Alphabet Inc.      NMS
# 6     MO                       Altria Group, Inc.      NYQ
# 7    DAL                    Delta Air Lines, Inc.      NYQ
# 8     AA                        Alcoa Corporation      NYQ
# 9    AXP                 American Express Company      NYQ
#
# 2                   Category Name Country
# 0                             NaN     USA
# 1            Electronic Equipment     USA
# 2              Money Center Banks     USA
# 3     Catalog & Mail Order Houses     USA
# 4     Telecom Services - Domestic     USA
# 5  Internet Information Providers     USA
# 6                      Cigarettes     USA
# 7                  Major Airlines     USA
# 8                        Aluminum     USA
# 9                 Credit Services     USA

# %% [markdown]
# <br/>
#
# #### Saving the list of stcks with tickers with `country_name` in a different `csv` file which can be used later.

# %%
new_df.to_csv('Assets'+os.sep+country_name+'.csv', sep=',', index=None)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 new_df.to_csv('Assets'+os.sep+country_name+'.csv', sep=',', index=None)
#
# File c:\Users\mgraffigna3\Anaconda3\envs\DMD\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File c:\Users\mgraffigna3\Anaconda3\envs\DMD\Lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\mgraffigna3\Anaconda3\envs\DMD\Lib\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File c:\Users\mgraffigna3\Anaconda3\envs\DMD\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'Assets\\USA.csv'

# %% [markdown]
#
# #### Now we got our `tickers` which we can find by company names
#
# <br/>
#
# ### Important Note
# We can scrap historical data for every stock mentioned on yahoo finance. But remember the data size. There are about **`8984`** stocks for only `India`. And if you want for every stocks, there is **`106328`** stocks. Which will take huge resources and time.
# Check out my brute force downloader **[stock-market-scraper](stock-market-scraper.py)** for downloading all datasets.

# %% [markdown]
# #### List down the company for which the stocks will be downloaded
# <br/>

# %%
desired_company_list = [ 'Igarashi Motors' ,
                        'State Bank of India' ,
                        'Tata Motors' ,
                        'Tata Consultancy Services' ]

# %%
category = new_df['Category Name'].unique()[1:]

# %%
desired_company_list = list(new_df[(new_df['Category Name']=='Credit Services')]['Name'].values)
len(desired_company_list)
# Out:
# 44

# %% [markdown]
# #### Get the ticker list for the companies user entered in the `desired_company_list`
# <br/>

# %%
ticker_list=[]
for company in desired_company_list:
    try:
        exact_company_name = (difflib.get_close_matches(company, new_df['Name'])[0])
        ticker_for_the_company = new_df.loc[new_df['Name'] == exact_company_name, 'Ticker'].iloc[0]
        ticker_list.append(ticker_for_the_company)
    except:
        print("Company name "+company+" not found.")

# %% [markdown]
# <br/>
#
# #### Now create the query urls for the stock `ticker`s. This will bring the query pages, where yahoo finance holds it's historical stock data.
#
# <br/>
#
# Example query is like this:  `https://query1.finance.yahoo.com/v8/finance/chart/`**ticker**`?symbol=`**ticker**`&period1=0&period2=9999999999&interval=1d&includePrePost=true&events=div%2Csplit`
#
# <br/>

# %%
query_urls=[]
for ticker in ticker_list:
    query_urls.append("https://query1.finance.yahoo.com/v8/finance/chart/"+ticker+"?symbol="+ticker+"&period1=0&period2=9999999999&interval=1d&includePrePost=true&events=div%2Csplit")

# %% [markdown]
# ### Now get to the stock datas with multithreading.
# <br/>

# %%
with Pool(processes=len(query_urls)) as pool:
    pool.starmap(get_historic_price, zip(query_urls, itertools.repeat(json_path), itertools.repeat(csv_path)))
print("All downloads completed !")
# Out:
# |||  Historical data of ONDK doesn't exist
# |||  Historical data of ISM doesn't exist
# |||  Historical data of CIT doesn't exist
# >>>  Historical data of CCCR exists but has no trading data
# >>>  Historical data of ATLCF exists but has no trading data
# |||  Historical data of COFI doesn't exist
# |||  Historical data of TSS doesn't exist
# >>>  Historical data of NEWS saved
# >>>  Historical data of LC saved
# >>>  Historical data of MSTO saved
# >>>  Historical data of HAWK saved
# >>>  Historical data of PYPL saved
# >>>  Historical data of WCRS saved
# >>>  Historical data of TCAP saved
# >>>  Historical data of ENVA saved
# >>>  Historical data of SYF saved
# >>>  Historical data of FPAY saved
# >>>  Historical data of RM saved
# >>>  Historical data of QIWI saved
# >>>  Historical data of GDOT saved
# >>>  Historical data of CPSS saved
# >>>  Historical data of MA saved
# >>>  Historical data of MGI saved
# >>>  Historical data of V saved
# >>>  Historical data of KNKT saved
# >>>  Historical data of PHH saved
# >>>  Historical data of DFS saved
# >>>  Historical data of WU saved
# >>>  Historical data of SRCO saved
# >>>  Historical data of NNI saved
# >>>  Historical data of ATLC saved
# >>>  Historical data of LOAN saved
# >>>  Historical data of IX saved
# >>>  Historical data of NICK saved
# >>>  Historical data of AGM saved
# >>>  Historical data of CACC saved
# >>>  Historical data of WRLD saved
# >>>  Historical data of FCFS saved
# >>>  Historical data of COF saved
# >>>  Historical data of EZPW saved
# >>>  Historical data of SNFCA saved
# >>>  Historical data of EFX saved
# >>>  Historical data of SLM saved
# >>>  Historical data of AXP saved
# All downloads completed !

# %% [markdown]
# ### All Categories

# %%
import urllib.request, json , time, os, difflib, itertools
import pandas as pd
from multiprocessing.dummy import Pool
from datetime import datetime

try:
    import httplib
except:
    import http.client as httplib

def check_internet():
    conn = httplib.HTTPConnection("www.google.com", timeout=5)
    try:
        conn.request("HEAD", "/")
        conn.close()
        # print("True")
        return True
    except:
        conn.close()
        # print("False")
        return False
    
def get_historic_price(query_url,json_path,csv_path):
    
    while not check_internet():
        print("Could not connect, trying again in 5 seconds...")
        time.sleep(5)
    
    stock_id=query_url.split("&period")[0].split("symbol=")[1]
    
    if os.path.exists(csv_path+stock_id+'.csv') and os.stat(csv_path+stock_id+'.csv').st_size != 0:
        print("<<<  Historical data of "+stock_id+" already exists, Updating data...")

    try:
        with urllib.request.urlopen(query_url) as url:
            parsed = json.loads(url.read().decode())
    except:
        print("|||  Historical data of "+stock_id+" doesn't exist")
        return
    
    else:
        if os.path.exists(json_path+stock_id+'.json'):
            os.remove(json_path+stock_id+'.json')
        with open(json_path+stock_id+'.json', 'w') as outfile:
            json.dump(parsed, outfile, indent=4)

        try:
            Date=[]
            for i in parsed['chart']['result'][0]['timestamp']:
                Date.append(datetime.utcfromtimestamp(int(i)).strftime('%d-%m-%Y'))

            Low=parsed['chart']['result'][0]['indicators']['quote'][0]['low']
            Open=parsed['chart']['result'][0]['indicators']['quote'][0]['open']
            Volume=parsed['chart']['result'][0]['indicators']['quote'][0]['volume']
            High=parsed['chart']['result'][0]['indicators']['quote'][0]['high']
            Close=parsed['chart']['result'][0]['indicators']['quote'][0]['close']
            Adjusted_Close=parsed['chart']['result'][0]['indicators']['adjclose'][0]['adjclose']

            df=pd.DataFrame(list(zip(Date,Low,Open,Volume,High,Close,Adjusted_Close)),columns =['Date','Low','Open','Volume','High','Close','Adjusted Close'])

            if os.path.exists(csv_path+stock_id+'.csv'):
                os.remove(csv_path+stock_id+'.csv')
            df.to_csv(csv_path+stock_id+'.csv', sep=',', index=None)
            print(">>>  Historical data of "+stock_id+" saved")
            return
        except:
            print(">>>  Historical data of "+stock_id+" exists but has no trading data")
country_name = "USA"
ticker_file_path = "Assets"+os.sep+"Yahoo Ticker Symbols - September 2017.xlsx"
temp_df = pd.read_excel(ticker_file_path)
print("Total stocks:",len(temp_df))
temp_df.head(10)

temp_df = temp_df.drop(temp_df.columns[[5, 6, 7]], axis=1)
headers = temp_df.iloc[2]
df  = pd.DataFrame(temp_df.values[3:], columns=headers)
print("Total stocks:",len(df))
df.head(10)
new_df = df[df["Country"].str.lower().str.contains(country_name.lower()) == True]
print("Total stocks:",len(new_df))
new_df.head(10)

# %%
for cat in category:

    try:
        desired_company_list = list(new_df[(new_df['Category Name']==cat)]['Name'].values)
        if len(desired_company_list)>10:
            json_path = os.getcwd()+os.sep+".."+os.sep+"historic_data"+os.sep+"json"+os.sep
            csv_path = os.getcwd()+os.sep+".."+os.sep+"historic_data"+os.sep+cat+os.sep
            if not os.path.isdir(json_path):
                os.makedirs(json_path)
            if not os.path.isdir(csv_path):
                os.makedirs(csv_path)

            ticker_list=[]
            for company in desired_company_list:
                try:
                    exact_company_name = (difflib.get_close_matches(company, new_df['Name'])[0])
                    ticker_for_the_company = new_df.loc[new_df['Name'] == exact_company_name, 'Ticker'].iloc[0]
                    ticker_list.append(ticker_for_the_company)
                except:
                    print("Company name "+company+" not found.")
            query_urls=[]
            for ticker in ticker_list:
                query_urls.append("https://query1.finance.yahoo.com/v8/finance/chart/"+ticker+"?symbol="+ticker+"&period1=0&period2=9999999999&interval=1d&includePrePost=true&events=div%2Csplit")
            with Pool(processes=len(query_urls)) as pool:
                pool.starmap(get_historic_price, zip(query_urls, itertools.repeat(json_path), itertools.repeat(csv_path)))
            print("All downloads completed !")
    except:
        print(cat)
# Out:
# |||  Historical data of GTMM doesn't exist
# |||  Historical data of SMDM doesn't exist
# |||  Historical data of MCIG doesn't exist
# |||  Historical data of SNE doesn't exist
# |||  Historical data of EDIG doesn't exist
# |||  Historical data of SGOC doesn't exist
# >>>  Historical data of KODK saved>>>  Historical data of WATT saved
#
# >>>  Historical data of VUZI saved
# >>>  Historical data of FN saved
# >>>  Historical data of MSN saved
# >>>  Historical data of UEIC saved
# >>>  Historical data of KOSS saved
# >>>  Historical data of PHG saved
# >>>  Historical data of AAPL saved
# All downloads completed !
# |||  Historical data of FCBI doesn't exist
# |||  Historical data of BHBK doesn't exist
# |||  Historical data of HBK doesn't exist
# |||  Historical data of FBNK doesn't exist
# |||  Historical data of GWB doesn't exist
# |||  Historical data of STI doesn't exist
# |||  Historical data of STL doesn't exist
# |||  Historical data of FSB doesn't exist
# |||  Historical data of EGDW doesn't exist
# |||  Historical data of NCBS doesn't exist
# >>>  Historical data of MTU exists but has no trading data
# >>>  Historical data of OAKV saved
# |||  Historical data of BLMT doesn't exist
# >>>  Historical data of CECB exists but has no trading data
# >>>  Historical data of WBKC exists but has no trading data
# >>>  Historical data of MTGB exists but has no trading data
# |||  Historical data of PUB doesn't exist
# |||  Historical data of TSC doesn't exist
# |||  Historical data of OPB doesn't exist
# >>>  Historical data of GNBC saved
# >>>  Historical data of PVBC saved
# >>>  Historical data of SFBC saved
# >>>  Historical data of FRC saved>>>  Historical data of STBZ saved
#
# >>>  Historical data of BMO saved
# >>>  Historical data of RY saved
# >>>  Historical data of HOMB saved
# >>>  Historical data of BNS saved
# >>>  Historical data of CBKM saved
# >>>  Historical data of SFST saved
# >>>  Historical data of UBOH saved
# >>>  Historical data of IBN saved
# >>>  Historical data of CM saved
# >>>  Historical data of TD saved
# >>>  Historical data of BSAC saved
# >>>  Historical data of UNTY saved
# >>>  Historical data of C saved
# >>>  Historical data of BAP saved
# >>>  Historical data of RNST saved
# >>>  Historical data of OFG saved
# >>>  Historical data of SFNC saved
# >>>  Historical data of CMA saved
# >>>  Historical data of JPM saved
# >>>  Historical data of PNC saved
# >>>  Historical data of BAC saved
# >>>  Historical data of WFC saved
# All downloads completed !
# |||  Historical data of MJMI doesn't exist
# >>>  Historical data of LVNTA exists but has no trading data
# >>>  Historical data of QVCA exists but has no trading data
# |||  Historical data of ATV doesn't exist
# >>>  Historical data of EVLV saved
# >>>  Historical data of BZUN saved
# >>>  Historical data of LITB saved
# >>>  Historical data of LE saved
# >>>  Historical data of VIPS saved
# >>>  Historical data of W saved
# >>>  Historical data of MELI saved
# >>>  Historical data of GPDB saved
# >>>  Historical data of LQDT saved
# >>>  Historical data of OSTK saved
# >>>  Historical data of GAIA saved
# >>>  Historical data of AMZN saved
# All downloads completed !
# |||  Historical data of CEL doesn't exist
# |||  Historical data of ALSK doesn't exist
# |||  Historical data of CTL doesn't exist
# |||  Historical data of OTEL doesn't exist
# |||  Historical data of INVT doesn't exist
# |||  Historical data of WIN doesn't exist
# |||  Historical data of FTR doesn't exist
# |||  Historical data of CBB doesn't exist
# >>>  Historical data of SGRB saved
# >>>  Historical data of CALL saved
# >>>  Historical data of CNSL saved
# >>>  Historical data of IMTO saved
# >>>  Historical data of CHT saved
# >>>  Historical data of SHEN saved
# >>>  Historical data of ATNI saved
# >>>  Historical data of BCE saved
# >>>  Historical data of VZ saved
# >>>  Historical data of T saved
# All downloads completed !
# |||  Historical data of MMRF doesn't exist
# |||  Historical data of MEET doesn't exist
# |||  Historical data of WUBA doesn't exist
# |||  Historical data of DLPME doesn't exist
# |||  Historical data of LLNW doesn't exist
# |||  Historical data of CRCM doesn't exist
# |||  Historical data of FB doesn't exist
# |||  Historical data of TWTR doesn't exist
# |||  Historical data of SYNC doesn't exist
# |||  Historical data of BCOR doesn't exist
# |||  Historical data of GRUB doesn't exist
# |||  Historical data of IMKI doesn't exist
# |||  Historical data of JRJC doesn't exist
# |||  Historical data of BITA doesn't exist
# >>>  Historical data of PAYM exists but has no trading data
# >>>  Historical data of GPLH exists but has no trading data
# >>>  Historical data of RATE saved
# |||  Historical data of SFUN doesn't exist
# |||  Historical data of ACLZ doesn't exist
# |||  Historical data of TST doesn't exist
# |||  Historical data of SURP doesn't exist
# |||  Historical data of CIIX doesn't exist
# >>>  Historical data of ABTL exists but has no trading data
# >>>  Historical data of Z saved
# >>>  Historical data of CHAA saved
# >>>  Historical data of ANAV saved
# >>>  Historical data of SBAY saved
# >>>  Historical data of PRSS saved
# >>>  Historical data of IPDN saved
# >>>  Historical data of CRTO saved
# >>>  Historical data of ATHM saved
# >>>  Historical data of WIX saved
# >>>  Historical data of WB saved
# >>>  Historical data of JD saved
# >>>  Historical data of YY saved
# >>>  Historical data of GRPN saved
# >>>  Historical data of YELP saved
# >>>  Historical data of FENG saved
# >>>  Historical data of TRIP saved
# >>>  Historical data of CCIH saved
# >>>  Historical data of ENGA saved
# >>>  Historical data of YNDX saved
# >>>  Historical data of GOOG saved
# >>>  Historical data of WEB saved
# >>>  Historical data of BIDU saved
# >>>  Historical data of SOHU saved
# >>>  Historical data of TTGT saved
# >>>  Historical data of MARK saved
# >>>  Historical data of TZOO saved
# >>>  Historical data of VRSN saved
# >>>  Historical data of AKAM saved
# >>>  Historical data of TCX saved
# >>>  Historical data of IAC saved
# Internet Information Providers
# |||  Historical data of CIT doesn't exist
# |||  Historical data of ONDK doesn't exist
# |||  Historical data of COFI doesn't exist
# |||  Historical data of TSS doesn't exist
# >>>  Historical data of ATLCF exists but has no trading data
# |||  Historical data of ISM doesn't exist
# >>>  Historical data of CCCR exists but has no trading data
# >>>  Historical data of HAWK saved
# >>>  Historical data of NEWS saved
# >>>  Historical data of ENVA saved
# >>>  Historical data of LC saved
# >>>  Historical data of TCAP saved
# >>>  Historical data of WCRS saved
# >>>  Historical data of PYPL saved
# >>>  Historical data of FPAY saved
# >>>  Historical data of QIWI saved
# >>>  Historical data of SYF saved
# >>>  Historical data of AGM saved
# >>>  Historical data of RM saved
# >>>  Historical data of GDOT saved
# >>>  Historical data of KNKT saved
# >>>  Historical data of MSTO saved
# >>>  Historical data of MA saved
# >>>  Historical data of V saved
# >>>  Historical data of MGI saved
# >>>  Historical data of DFS saved
# >>>  Historical data of WU saved
# >>>  Historical data of IX saved
# >>>  Historical data of PHH saved
# >>>  Historical data of NNI saved
# >>>  Historical data of SRCO saved
# >>>  Historical data of LOAN saved
# >>>  Historical data of ATLC saved
# >>>  Historical data of NICK saved>>>  Historical data of WRLD saved
#
# >>>  Historical data of SNFCA saved
# >>>  Historical data of CACC saved
# >>>  Historical data of CPSS saved
# >>>  Historical data of COF saved
# >>>  Historical data of EZPW saved
# >>>  Historical data of FCFS saved
# >>>  Historical data of EFX saved
# >>>  Historical data of SLM saved
# >>>  Historical data of AXP saved
# All downloads completed !
# |||  Historical data of MBII doesn't exist
# |||  Historical data of MON doesn't exist
# |||  Historical data of GROG doesn't exist
# >>>  Historical data of POT exists but has no trading data
# >>>  Historical data of AGU exists but has no trading data
# >>>  Historical data of SYT saved
# >>>  Historical data of RTK exists but has no trading data
# >>>  Historical data of RKDA saved
# >>>  Historical data of CGA saved
# >>>  Historical data of IPI saved
# >>>  Historical data of UAN saved
# >>>  Historical data of CVAT saved
# >>>  Historical data of KWBT saved
# >>>  Historical data of CF saved
# >>>  Historical data of TNH saved
# >>>  Historical data of SMG saved
# >>>  Historical data of MOS saved
# >>>  Historical data of AVD saved
# >>>  Historical data of DD saved
# All downloads completed !
# |||  Historical data of PRTY doesn't exist
# |||  Historical data of BID doesn't exist
# >>>  Historical data of WMAR exists but has no trading data
# >>>  Historical data of HOLL exists but has no trading data
# >>>  Historical data of HSNI exists but has no trading data
# >>>  Historical data of SPLS exists but has no trading data
# |||  Historical data of ZAGG doesn't exist
# >>>  Historical data of PERF saved
# |||  Historical data of TUMIF doesn't exist
# |||  Historical data of FTD doesn't exist
# |||  Historical data of ELTZ doesn't exist
# |||  Historical data of PCMI doesn't exist
# |||  Historical data of MIK doesn't exist
# |||  Historical data of CSS doesn't exist
# |||  Historical data of VSI doesn't exist
# |||  Historical data of BKS doesn't exist
# |||  Historical data of OMNTD doesn't exist
# |||  Historical data of PIR doesn't exist
# |||  Historical data of PMXO doesn't exist
# >>>  Historical data of ETSY saved
# |||  Historical data of JMEI doesn't exist
# >>>  Historical data of TA saved
# >>>  Historical data of BNED saved
# >>>  Historical data of BABA saved
# >>>  Historical data of HADV saved
# >>>  Historical data of MUSA saved
# >>>  Historical data of PRTS saved
# >>>  Historical data of FIVE saved
# >>>  Historical data of TCS saved
# >>>  Historical data of ULTA saved
# >>>  Historical data of KAR saved
# >>>  Historical data of SBH saved
# >>>  Historical data of ZUMZ saved
# >>>  Historical data of XOXO saved
# >>>  Historical data of FLWS saved
# >>>  Historical data of HZO saved
# >>>  Historical data of WINA saved
# >>>  Historical data of EBAY saved
# >>>  Historical data of MED saved
# >>>  Historical data of FINL saved
# >>>  Historical data of TSCO saved
# >>>  Historical data of ODP saved
# >>>  Historical data of GPC saved
# All downloads completed !
# |||  Historical data of LEDIF doesn't exist
# |||  Historical data of DRAD doesn't exist
# |||  Historical data of NEMD doesn't exist
# |||  Historical data of GNMK doesn't exist
# |||  Historical data of ALRT doesn't exist
# |||  Historical data of VAR doesn't exist
# |||  Historical data of IVOB doesn't exist
# |||  Historical data of XENT doesn't exist
# |||  Historical data of EYES doesn't exist
# >>>  Historical data of ACAR exists but has no trading data
# |||  Historical data of RTIX doesn't exist
# |||  Historical data of IVC doesn't exist
# >>>  Historical data of AIRW exists but has no trading data
# >>>  Historical data of AMDA exists but has no trading data
# |||  Historical data of WMGI doesn't exist
# |||  Historical data of MSON doesn't exist
# |||  Historical data of KOOL doesn't exist
# |||  Historical data of SCVM doesn't exist
# >>>  Historical data of VSUL exists but has no trading data
# >>>  Historical data of ETRM exists but has no trading data
# |||  Historical data of CRY doesn't exist
# |||  Historical data of CVRS doesn't exist
# |||  Historical data of MRIC doesn't exist
# |||  Historical data of MDVX doesn't exist
# >>>  Historical data of GTHP saved
# >>>  Historical data of EVAR exists but has no trading data
# |||  Historical data of NXTM doesn't exist
# |||  Historical data of WNDM doesn't exist
# >>>  Historical data of BABY saved
# |||  Historical data of SPNE doesn't exist
# >>>  Historical data of PHMD exists but has no trading data
# >>>  Historical data of MGCD exists but has no trading data
# >>>  Historical data of CGNT saved
# >>>  Historical data of NMRD saved
# >>>  Historical data of ARTH saved
# >>>  Historical data of VRAY saved
# >>>  Historical data of SMLR saved
# >>>  Historical data of NUMD saved
# >>>  Historical data of IRMD saved
# >>>  Historical data of LCTC saved
# >>>  Historical data of AVGR saved
# >>>  Historical data of KTWO saved
# >>>  Historical data of NAOV saved
# >>>  Historical data of TSNI saved>>>  Historical data of GMED saved
#
# >>>  Historical data of RWLK saved
# >>>  Historical data of OXYS saved
# >>>  Historical data of SNWV saved>>>  Historical data of NSPR saved
#
# >>>  Historical data of NVRO saved
# >>>  Historical data of LCDX saved
# >>>  Historical data of VICA saved
# >>>  Historical data of ACRX saved
# >>>  Historical data of CRVW saved>>>  Historical data of MDXG saved
#
# >>>  Historical data of AEMD saved
# >>>  Historical data of ARAY saved
# >>>  Historical data of SCIE saved
# >>>  Historical data of ELMD saved
# >>>  Historical data of MASI saved
# >>>  Historical data of CGHC saved
# >>>  Historical data of ZYXI saved
# >>>  Historical data of PBIO saved
# >>>  Historical data of CSII saved
# >>>  Historical data of RSCF saved
# >>>  Historical data of EXAC saved
# >>>  Historical data of PUMD saved
# >>>  Historical data of NUVA saved
# >>>  Historical data of PBH saved
# >>>  Historical data of EDAP saved
# >>>  Historical data of STXS saved
# >>>  Historical data of CUTR saved
# >>>  Historical data of POSC saved
# >>>  Historical data of ZBH saved
# >>>  Historical data of EW saved
# >>>  Historical data of DYNT saved
# >>>  Historical data of ALGN saved
# >>>  Historical data of ESMC saved
# >>>  Historical data of ISRG saved
# >>>  Historical data of VASO saved
# >>>  Historical data of RMD saved
# >>>  Historical data of HOLX saved
# >>>  Historical data of STE saved
# >>>  Historical data of ULGX saved
# >>>  Historical data of SNN saved
# >>>  Historical data of FONR saved
# >>>  Historical data of BLFS saved
# >>>  Historical data of NIMU saved
# >>>  Historical data of OFIX saved
# >>>  Historical data of AXGN saved
# >>>  Historical data of IRIX saved
# >>>  Historical data of AHPI saved
# >>>  Historical data of BSX saved
# >>>  Historical data of ABMD saved
# >>>  Historical data of CNMD saved
# >>>  Historical data of ABT saved
# >>>  Historical data of SYK saved
# >>>  Historical data of MDT saved
# All downloads completed !
# |||  Historical data of SQBG doesn't exist
# >>>  Historical data of KORS exists but has no trading data
# |||  Historical data of EVK doesn't exist
# |||  Historical data of HHWW doesn't exist
# >>>  Historical data of XNY exists but has no trading data
# |||  Historical data of KBSF doesn't exist
# >>>  Historical data of UA saved
# >>>  Historical data of XELB saved
# >>>  Historical data of VNCE saved
# >>>  Historical data of GIL saved
# >>>  Historical data of DLA saved
# >>>  Historical data of LULU saved
# >>>  Historical data of HBI saved
# >>>  Historical data of CRI saved
# >>>  Historical data of CRWS saved
# >>>  Historical data of TALN saved
# >>>  Historical data of COLM saved
# >>>  Historical data of PERY saved
# >>>  Historical data of RL saved
# >>>  Historical data of GIII saved
# >>>  Historical data of UNF saved
# >>>  Historical data of OXM saved
# >>>  Historical data of PVH saved
# >>>  Historical data of SGC saved
# >>>  Historical data of VFC saved
# All downloads completed !
# |||  Historical data of NANO doesn't exist
# |||  Historical data of BRKS doesn't exist
# |||  Historical data of CREE doesn't exist
# |||  Historical data of IMI doesn't exist
# >>>  Historical data of AMBA saved
# >>>  Historical data of STRI saved
# >>>  Historical data of ENPH saved
# >>>  Historical data of OLED saved
# >>>  Historical data of DQ saved
# >>>  Historical data of OCLR saved
# >>>  Historical data of RBCN saved
# >>>  Historical data of IPGP saved
# >>>  Historical data of ACLS saved
# >>>  Historical data of NVMI saved
# >>>  Historical data of IMOS saved
# >>>  Historical data of SODI saved
# >>>  Historical data of ENTG saved
# >>>  Historical data of AEHR saved
# >>>  Historical data of ASX saved
# >>>  Historical data of UMC saved
# >>>  Historical data of EMAN saved
# >>>  Historical data of SNPS saved
# >>>  Historical data of ASYS saved
# >>>  Historical data of CAMT saved
# >>>  Historical data of TRT saved
# >>>  Historical data of PLAB saved
# >>>  Historical data of VECO saved
# >>>  Historical data of XCRA saved
# >>>  Historical data of KLAC saved
# >>>  Historical data of KLIC saved
# >>>  Historical data of COHU saved
# >>>  Historical data of LRCX saved
# >>>  Historical data of PKE saved
# >>>  Historical data of AMAT saved
# >>>  Historical data of TER saved
# All downloads completed !
# |||  Historical data of ADRO doesn't exist
# |||  Historical data of AIMT doesn't exist
# |||  Historical data of ALXN doesn't exist
# |||  Historical data of AST doesn't exist
# |||  Historical data of EARS doesn't exist
# |||  Historical data of SYN doesn't exist
# |||  Historical data of BTX doesn't exist
# |||  Historical data of HTBX doesn't exist
# |||  Historical data of HEB doesn't exist
# |||  Historical data of FWP doesn't exist
# |||  Historical data of ADLS doesn't exist
# |||  Historical data of ARNA doesn't exist
# |||  Historical data of AKAO doesn't exist
# |||  Historical data of GNCA doesn't exist
# |||  Historical data of PETX doesn't exist
# |||  Historical data of APHB doesn't exist
# |||  Historical data of AMAR doesn't exist
# |||  Historical data of AVEO doesn't exist
# >>>  Historical data of EBIO exists but has no trading data
# |||  Historical data of ARQL doesn't exist
# |||  Historical data of ALDR doesn't exist
# |||  Historical data of XLRN doesn't exist
# |||  Historical data of PDLI doesn't exist
# |||  Historical data of GBT doesn't exist
# >>>  Historical data of AMRI exists but has no trading data
# >>>  Historical data of ADHD exists but has no trading data
# |||  Historical data of CBPO doesn't exist
# |||  Historical data of CBLI doesn't exist
# |||  Historical data of KIN doesn't exist
# |||  Historical data of BSTC doesn't exist
# |||  Historical data of ORPN doesn't exist
# |||  Historical data of CELG doesn't exist
# |||  Historical data of BPMX doesn't exist
# |||  Historical data of BTHE doesn't exist
# |||  Historical data of OMBP doesn't exist
# >>>  Historical data of PBMD exists but has no trading data
# |||  Historical data of XON doesn't exist
# |||  Historical data of CYTX doesn't exist
# >>>  Historical data of PRGB exists but has no trading data
# >>>  Historical data of ENUM exists but has no trading data
# |||  Historical data of CLSN doesn't exist
# >>>  Historical data of CEMP exists but has no trading data
# |||  Historical data of CBM doesn't exist
# |||  Historical data of NLNK doesn't exist
# |||  Historical data of CYTR doesn't exist
# |||  Historical data of CNAT doesn't exist
# |||  Historical data of CLVS doesn't exist
# |||  Historical data of CTRV doesn't exist
# >>>  Historical data of ACHN saved
# |||  Historical data of CCXI doesn't exist
# |||  Historical data of OPHT doesn't exist
# |||  Historical data of CHMA doesn't exist
# |||  Historical data of LJPC doesn't exist
# |||  Historical data of CUR doesn't exist
# >>>  Historical data of ITEK exists but has no trading data
# |||  Historical data of DGJI doesn't exist
# |||  Historical data of DRNA doesn't exist
# >>>  Historical data of RXII exists but has no trading data
# |||  Historical data of EGLT doesn't exist
# |||  Historical data of EYEG doesn't exist
# |||  Historical data of VODG doesn't exist
# |||  Historical data of EPZM doesn't exist
# |||  Historical data of FPRX doesn't exist
# |||  Historical data of EMIS doesn't exist
# |||  Historical data of RDUS doesn't exist
# >>>  Historical data of ENZY exists but has no trading data
# |||  Historical data of FOMX doesn't exist
# |||  Historical data of FLKS doesn't exist
# |||  Historical data of ZIOP doesn't exist
# |||  Historical data of GTXI doesn't exist
# >>>  Historical data of PANG exists but has no trading data
# |||  Historical data of HSGX doesn't exist
# |||  Historical data of VVUS doesn't exist
# |||  Historical data of IDRA doesn't exist
# |||  Historical data of PTLA doesn't exist
# |||  Historical data of ONCE doesn't exist
# >>>  Historical data of OVAS exists but has no trading data
# >>>  Historical data of PPHM exists but has no trading data
# |||  Historical data of INSY doesn't exist
# |||  Historical data of OSIR doesn't exist
# |||  Historical data of VICL doesn't exist|||  Historical data of ZFGN doesn't exist
#
# |||  Historical data of IMMU doesn't exist
# >>>  Historical data of COOL saved
# >>>  Historical data of ARRY saved
# |||  Historical data of OHRP doesn't exist
# >>>  Historical data of DERM saved
# |||  Historical data of SNSS doesn't exist
# |||  Historical data of RNN doesn't exist
# >>>  Historical data of KITE exists but has no trading data
# |||  Historical data of PGNX doesn't exist
# |||  Historical data of PSTI doesn't exist
# >>>  Historical data of GALE saved
# |||  Historical data of NK doesn't exist
# |||  Historical data of PTIE doesn't exist
# >>>  Historical data of IMMY exists but has no trading data
# >>>  Historical data of NDRM exists but has no trading data
# >>>  Historical data of OCRX exists but has no trading data
# |||  Historical data of LOXO doesn't exist
# |||  Historical data of NMUS doesn't exist
# |||  Historical data of OMED doesn't exist
# >>>  Historical data of NEOT exists but has no trading data
# |||  Historical data of ZSAN doesn't exist
# >>>  Historical data of OPXA exists but has no trading data
# >>>  Historical data of ILNS exists but has no trading data
# |||  Historical data of CATB doesn't exist
# |||  Historical data of REPH doesn't exist
# |||  Historical data of PFNX doesn't exist
# >>>  Historical data of OPLI exists but has no trading data
# |||  Historical data of RTTR doesn't exist
# |||  Historical data of PRTO doesn't exist
# |||  Historical data of PTEO doesn't exist
# |||  Historical data of VTL doesn't exist
# |||  Historical data of STML doesn't exist
# >>>  Historical data of DDRT exists but has no trading data
# >>>  Historical data of ICPTF exists but has no trading data
# >>>  Historical data of TPIV exists but has no trading data
# |||  Historical data of AJACD doesn't exist
# |||  Historical data of CBBT doesn't exist
# >>>  Historical data of GOVX saved
# >>>  Historical data of SVON exists but has no trading data
# |||  Historical data of CCAN doesn't exist
# >>>  Historical data of ANTB exists but has no trading data
# >>>  Historical data of JAGX saved
# >>>  Historical data of SIGAQ exists but has no trading data
# >>>  Historical data of IMUC saved
# >>>  Historical data of RPRX saved
# >>>  Historical data of RXDX saved
# >>>  Historical data of BLCM saved
# >>>  Historical data of LIFE saved
# >>>  Historical data of CANF saved
# >>>  Historical data of IMCL saved
# >>>  Historical data of CLCS saved
# >>>  Historical data of ATHX saved
# >>>  Historical data of ASND saved
# >>>  Historical data of ADAP saved
# >>>  Historical data of BPMC saved
# >>>  Historical data of CORI saved
# >>>  Historical data of ALDX saved
# >>>  Historical data of ATNM saved
# >>>  Historical data of JUNO saved
# >>>  Historical data of AKBA saved
# >>>  Historical data of CALA saved
# >>>  Historical data of BLPH saved
# >>>  Historical data of AFMD saved
# >>>  Historical data of CDTX saved
# >>>  Historical data of NVIV saved
# >>>  Historical data of ARDX saved
# >>>  Historical data of CRBP saved
# >>>  Historical data of RGBP saved
# >>>  Historical data of ADMA saved
# >>>  Historical data of TBPH saved
# >>>  Historical data of BLUE saved
# >>>  Historical data of AGIO saved
# >>>  Historical data of CHRS saved
# >>>  Historical data of BIEI saved
# >>>  Historical data of CNCE saved
# >>>  Historical data of FGEN saved
# >>>  Historical data of CARA saved
# >>>  Historical data of ONTX saved>>>  Historical data of ECYT saved
#
# >>>  Historical data of KMPH saved>>>  Historical data of ESPR saved
#
# >>>  Historical data of TRVN saved
# >>>  Historical data of GBIM saved
# >>>  Historical data of CBAY saved
# >>>  Historical data of PULM saved
# >>>  Historical data of MCRB saved
# >>>  Historical data of PRTA saved
# >>>  Historical data of TCON saved
# >>>  Historical data of OTIC saved
# >>>  Historical data of PBYI saved
# >>>  Historical data of GLYC saved
# >>>  Historical data of NERV saved
# >>>  Historical data of ACST saved
# >>>  Historical data of OCUL saved
# >>>  Historical data of TLOG saved
# >>>  Historical data of AMPE saved
# >>>  Historical data of FATE saved
# >>>  Historical data of RARE saved
# >>>  Historical data of FBIO saved
# >>>  Historical data of PRQR saved
# >>>  Historical data of PIRS saved
# >>>  Historical data of SAGE saved
# >>>  Historical data of MDWD saved
# >>>  Historical data of GLMD saved
# >>>  Historical data of CMRX saved>>>  Historical data of RVNC saved
#
# >>>  Historical data of XBIT saved
# >>>  Historical data of CRYO saved
# >>>  Historical data of CDXI saved
# >>>  Historical data of RGLS saved
# >>>  Historical data of XENE saved
# >>>  Historical data of ONCS saved
# >>>  Historical data of ITCI saved
# >>>  Historical data of CFRX saved
# >>>  Historical data of VKTX saved
# >>>  Historical data of IBIO saved
# >>>  Historical data of ENTA saved
# >>>  Historical data of TSRO saved
# >>>  Historical data of NSTG saved
# >>>  Historical data of PACB saved
# >>>  Historical data of QURE saved
# >>>  Historical data of PTCT saved
# >>>  Historical data of AMBS saved
# >>>  Historical data of MGNX saved
# >>>  Historical data of CLRB saved
# >>>  Historical data of MRTX saved
# >>>  Historical data of HDVY saved
# >>>  Historical data of MRNS saved
# >>>  Historical data of CRMD saved
# >>>  Historical data of BSTG saved
# >>>  Historical data of ICPT saved
# >>>  Historical data of CAPR saved
# >>>  Historical data of OMER saved>>>  Historical data of MACK saved
#
# >>>  Historical data of VSTM saved
# >>>  Historical data of GTHR saved
# >>>  Historical data of XXII saved
# >>>  Historical data of FPMI saved
# >>>  Historical data of XNCR saved
# >>>  Historical data of VBIV saved
# >>>  Historical data of CLVSF saved
# >>>  Historical data of NPHC saved
# >>>  Historical data of VCYT saved
# >>>  Historical data of EVGN saved
# >>>  Historical data of AEZS saved
# >>>  Historical data of ARNI saved
# >>>  Historical data of NBY saved
# >>>  Historical data of CDXS saved
# >>>  Historical data of TGTX saved
# >>>  Historical data of RAREF saved
# >>>  Historical data of AFFY saved
# >>>  Historical data of ANTH saved
# >>>  Historical data of ISCO saved
# >>>  Historical data of FOLD saved
# >>>  Historical data of CBIO saved
# >>>  Historical data of OGEN saved
# >>>  Historical data of ABUS saved
# >>>  Historical data of JAZZ saved
# >>>  Historical data of CSBR saved
# >>>  Historical data of ADXS saved
# >>>  Historical data of EBS saved
# >>>  Historical data of ERGO saved
# >>>  Historical data of ACOR saved
# >>>  Historical data of CYTK saved
# >>>  Historical data of MNKD saved
# >>>  Historical data of PRTK saved
# >>>  Historical data of AVXL saved
# >>>  Historical data of RGIN saved
# >>>  Historical data of BCLI saved
# >>>  Historical data of ALNY saved
# >>>  Historical data of ALSE saved
# >>>  Historical data of DVAX saved
# >>>  Historical data of CAPS saved
# >>>  Historical data of KERX saved
# >>>  Historical data of BDSI saved
# >>>  Historical data of MNOV saved
# >>>  Historical data of CORT saved
# >>>  Historical data of SRNE saved
# >>>  Historical data of CRIS saved
# >>>  Historical data of ACAD saved
# >>>  Historical data of SVA saved
# >>>  Historical data of CTIC saved
# >>>  Historical data of ORMP saved
# >>>  Historical data of HALO saved
# >>>  Historical data of PLX saved
# >>>  Historical data of VNDA saved
# >>>  Historical data of ABIO saved
# >>>  Historical data of CRXM saved
# >>>  Historical data of ANIP saved
# >>>  Historical data of SGEN saved
# >>>  Historical data of OMMH saved
# >>>  Historical data of TENX saved
# >>>  Historical data of BMRN saved
# >>>  Historical data of AXON saved
# >>>  Historical data of NWBO saved
# >>>  Historical data of CASI saved
# >>>  Historical data of CGEN saved
# >>>  Historical data of SNGX saved
# >>>  Historical data of EXEL saved
# >>>  Historical data of ARWR saved
# >>>  Historical data of SGMO saved
# >>>  Historical data of CERS saved
# >>>  Historical data of VCEL saved
# >>>  Historical data of INSM saved
# >>>  Historical data of NAVB saved
# >>>  Historical data of PLPL saved
# >>>  Historical data of SRPT saved
# >>>  Historical data of INFI saved
# >>>  Historical data of RCAR saved
# >>>  Historical data of NVAX saved
# >>>  Historical data of ILMN saved
# >>>  Historical data of QMDT saved
# >>>  Historical data of BCRX saved
# >>>  Historical data of ANIK saved
# >>>  Historical data of XOMA saved
# >>>  Historical data of INO saved
# >>>  Historical data of AGEN saved
# >>>  Historical data of LXRX saved
# >>>  Historical data of KDUS saved
# >>>  Historical data of CVM saved
# >>>  Historical data of SPPI saved
# >>>  Historical data of OPK saved
# >>>  Historical data of GERN saved
# >>>  Historical data of CLDX saved
# >>>  Historical data of HMGN saved
# >>>  Historical data of NKTR saved
# >>>  Historical data of IMGN saved
# >>>  Historical data of TECH saved
# >>>  Historical data of INCY saved
# >>>  Historical data of REGN saved>>>  Historical data of VRTX saved
#
# >>>  Historical data of TTNP saved
# >>>  Historical data of CYAN saved
# >>>  Historical data of RGEN saved
# >>>  Historical data of LGND saved
# >>>  Historical data of ICCC saved
# >>>  Historical data of BIIB saved
# >>>  Historical data of ENZN saved
# >>>  Historical data of GILD saved
# >>>  Historical data of PARD saved
# >>>  Historical data of AMGN saved
# All downloads completed !
# |||  Historical data of Y doesn't exist
# |||  Historical data of EMCI doesn't exist
# |||  Historical data of STFC doesn't exist
# |||  Historical data of FNHC doesn't exist
# |||  Historical data of NGHC doesn't exist
# |||  Historical data of AFH doesn't exist
# |||  Historical data of ANAT doesn't exist
# |||  Historical data of PIH doesn't exist
# >>>  Historical data of AGII exists but has no trading data
# >>>  Historical data of VR saved
# |||  Historical data of NSEC doesn't exist
# >>>  Historical data of SNC exists but has no trading data
# |||  Historical data of BCRH doesn't exist
# >>>  Historical data of BWINB exists but has no trading data
# |||  Historical data of TPRE doesn't exist
# |||  Historical data of XL doesn't exist
# |||  Historical data of NAVG doesn't exist
# >>>  Historical data of HRTG saved
# >>>  Historical data of AHL saved
# >>>  Historical data of CUII saved
# >>>  Historical data of FAF saved
# >>>  Historical data of CNFR saved
# >>>  Historical data of AFSI saved
# >>>  Historical data of JRVR saved
# >>>  Historical data of UIHC saved
# >>>  Historical data of IPCC saved
# >>>  Historical data of HCI saved
# >>>  Historical data of UVE saved
# >>>  Historical data of MHLD saved
# >>>  Historical data of AXS saved
# >>>  Historical data of DGICA saved
# >>>  Historical data of KFS saved
# >>>  Historical data of AMSF saved
# >>>  Historical data of THG saved
# >>>  Historical data of GBLI saved
# >>>  Historical data of SAFT saved
# >>>  Historical data of MKL saved
# >>>  Historical data of KINS saved
# >>>  Historical data of ALL saved
# >>>  Historical data of WTM saved
# >>>  Historical data of ESGR saved
# >>>  Historical data of MCY saved
# >>>  Historical data of HALL saved
# >>>  Historical data of HMN saved
# >>>  Historical data of SLF saved
# >>>  Historical data of BRK-A saved
# >>>  Historical data of RE saved
# >>>  Historical data of ACGL saved
# >>>  Historical data of HIG saved
# >>>  Historical data of UNAM saved
# >>>  Historical data of RNR saved
# >>>  Historical data of MTG saved
# >>>  Historical data of RDN saved
# >>>  Historical data of CB saved
# >>>  Historical data of KMPR saved
# >>>  Historical data of MBI saved
# >>>  Historical data of L saved
# >>>  Historical data of CINF saved
# >>>  Historical data of PGR saved
# >>>  Historical data of STC saved
# >>>  Historical data of SIGI saved
# >>>  Historical data of RLI saved
# >>>  Historical data of UFCS saved
# >>>  Historical data of TRV saved
# >>>  Historical data of AFG saved
# >>>  Historical data of ORI saved
# >>>  Historical data of CNA saved
# >>>  Historical data of AIG saved
# >>>  Historical data of WRB saved
# All downloads completed !
# |||  Historical data of GSB doesn't exist
# |||  Historical data of AMBR doesn't exist
# |||  Historical data of OHGI doesn't exist
# |||  Historical data of EIGI doesn't exist
# |||  Historical data of CDK doesn't exist
# |||  Historical data of CSOD doesn't exist
# |||  Historical data of ZIXI doesn't exist
# |||  Historical data of DATA doesn't exist>>>  Historical data of BSFT exists but has no trading data
#
# |||  Historical data of STMP doesn't exist
# |||  Historical data of BNFT doesn't exist
# |||  Historical data of CSLT doesn't exist
# |||  Historical data of TYPE doesn't exist
# |||  Historical data of LOGM doesn't exist
# |||  Historical data of EGOV doesn't exist
# |||  Historical data of FLKM doesn't exist
# |||  Historical data of LXFT doesn't exist
# |||  Historical data of EXNT doesn't exist
# |||  Historical data of FNJN doesn't exist
# |||  Historical data of DEAC doesn't exist
# |||  Historical data of ADVC doesn't exist
# |||  Historical data of ATEA doesn't exist
# |||  Historical data of FIND doesn't exist
# |||  Historical data of FEYE doesn't exist
# |||  Historical data of RHT doesn't exist
# |||  Historical data of NUAN doesn't exist
# |||  Historical data of PFPT doesn't exist
# |||  Historical data of ZEN doesn't exist
# >>>  Historical data of NQ exists but has no trading data
# |||  Historical data of ELLI doesn't exist
# |||  Historical data of RP doesn't exist
# |||  Historical data of TISA doesn't exist
# |||  Historical data of ECOM doesn't exist
# >>>  Historical data of DPDM exists but has no trading data
# |||  Historical data of RST doesn't exist
# >>>  Historical data of EXA exists but has no trading data
# |||  Historical data of MB doesn't exist
# >>>  Historical data of GUID exists but has no trading data
# >>>  Historical data of GBSX exists but has no trading data
# >>>  Historical data of CNIT exists but has no trading data
# |||  Historical data of MJCO doesn't exist
# |||  Historical data of VCSY doesn't exist
# >>>  Historical data of MXPT exists but has no trading data
# |||  Historical data of PTI doesn't exist
# |||  Historical data of RUBI doesn't exist
# >>>  Historical data of ARIS saved
# |||  Historical data of SRNA doesn't exist
# >>>  Historical data of APPO exists but has no trading data
# |||  Historical data of ISNS doesn't exist
# |||  Historical data of SAAX doesn't exist
# >>>  Historical data of DPSI saved
# >>>  Historical data of MBLY saved
# >>>  Historical data of PWEB exists but has no trading data
# >>>  Historical data of CDIF exists but has no trading data
# |||  Historical data of QADA doesn't exist
# >>>  Historical data of CNCK exists but has no trading data
# |||  Historical data of STOY doesn't exist
# >>>  Historical data of PDVW exists but has no trading data
# >>>  Historical data of RACK saved
# >>>  Historical data of TRMR saved
# >>>  Historical data of BV saved
# >>>  Historical data of HUGE saved
# >>>  Historical data of APPF saved
# >>>  Historical data of MOBL saved
# >>>  Historical data of APHD saved
# >>>  Historical data of CMCM saved
# >>>  Historical data of TLCC saved
# >>>  Historical data of UPLD saved
# >>>  Historical data of ALRM saved
# >>>  Historical data of FIVN saved
# >>>  Historical data of XNET saved
# >>>  Historical data of HUBS saved
# >>>  Historical data of MTLS saved
# >>>  Historical data of ANY saved
# >>>  Historical data of IMPV saved
# >>>  Historical data of PCTY saved
# >>>  Historical data of BOX saved
# >>>  Historical data of RPD saved
# >>>  Historical data of MRIN saved
# >>>  Historical data of KEYW saved
# >>>  Historical data of WK saved
# >>>  Historical data of MODN saved
# >>>  Historical data of RNG saved
# >>>  Historical data of WDAY saved
# >>>  Historical data of PAYC saved
# >>>  Historical data of SHOP saved
# >>>  Historical data of PFSF saved
# >>>  Historical data of SPLK saved
# >>>  Historical data of MUSS saved
# >>>  Historical data of INLX saved
# >>>  Historical data of XFCH saved
# >>>  Historical data of BLIN saved
# >>>  Historical data of QLYS saved
# >>>  Historical data of BCOV saved
# >>>  Historical data of TWOU saved>>>  Historical data of FALC saved
#
# >>>  Historical data of SSNT saved
# >>>  Historical data of OPNT saved
# >>>  Historical data of PLFX saved
# >>>  Historical data of SPSC saved
# >>>  Historical data of APPS saved
# >>>  Historical data of FTNT saved
# >>>  Historical data of WDDD saved
# >>>  Historical data of CVLT saved
# >>>  Historical data of SNCR saved
# >>>  Historical data of PRO saved
# >>>  Historical data of AVOI saved
# >>>  Historical data of VSMR saved
# >>>  Historical data of CRM saved
# >>>  Historical data of MATR saved
# >>>  Historical data of ACTA saved
# >>>  Historical data of NTWK saved
# >>>  Historical data of INVA saved>>>  Historical data of BSQR saved
#
# >>>  Historical data of SOFO saved
# >>>  Historical data of IDN saved
# >>>  Historical data of MDRX saved
# >>>  Historical data of IMMR saved
# >>>  Historical data of SYNA saved
# >>>  Historical data of MSTR saved
# >>>  Historical data of PLUS saved
# >>>  Historical data of MANH saved
# >>>  Historical data of AWRE saved
# >>>  Historical data of ANSS saved
# >>>  Historical data of OTEX saved
# >>>  Historical data of SMSI saved
# >>>  Historical data of SEAC saved
# >>>  Historical data of NSIT saved
# >>>  Historical data of SAP saved
# >>>  Historical data of MITK saved
# >>>  Historical data of INTU saved
# >>>  Historical data of MGIC saved
# >>>  Historical data of ADBE saved
# >>>  Historical data of PRGS saved
# >>>  Historical data of CDNS saved
# >>>  Historical data of ORCL saved
# >>>  Historical data of PAR saved
# >>>  Historical data of AMSWA saved
# >>>  Historical data of AGYS saved
# All downloads completed !
# >>>  Historical data of ACXM exists but has no trading data
# >>>  Historical data of ETEC saved
# |||  Historical data of VRTU doesn't exist
# >>>  Historical data of TEAM saved
# |||  Historical data of SPIN doesn't exist
# |||  Historical data of CHGT doesn't exist
# >>>  Historical data of QFOR exists but has no trading data
# |||  Historical data of INAP doesn't exist
# |||  Historical data of SYKE doesn't exist
# >>>  Historical data of GLOB saved
# >>>  Historical data of SAIC saved
# >>>  Historical data of NOW saved
# >>>  Historical data of CDW saved
# >>>  Historical data of EPAM saved
# >>>  Historical data of ICLD saved
# >>>  Historical data of SABR saved
# >>>  Historical data of ISDR saved
# >>>  Historical data of VNET saved
# >>>  Historical data of WYY saved
# >>>  Historical data of RDWR saved
# >>>  Historical data of HMNY saved
# >>>  Historical data of DMRC saved
# >>>  Historical data of ACN saved
# >>>  Historical data of EDGW saved
# >>>  Historical data of PRFT saved
# >>>  Historical data of MNDO saved
# >>>  Historical data of NCR saved
# >>>  Historical data of WIT saved
# >>>  Historical data of SYNT saved>>>  Historical data of FIS saved
#
# >>>  Historical data of IT saved
# >>>  Historical data of CACI saved
# >>>  Historical data of CSPI saved
# >>>  Historical data of CTG saved
# >>>  Historical data of UIS saved
# >>>  Historical data of IBM saved
# >>>  Historical data of XRX saved
# All downloads completed !
# >>>  Historical data of AXN exists but has no trading data
# |||  Historical data of HBMK doesn't exist
# |||  Historical data of AERI doesn't exist
# |||  Historical data of ALQA doesn't exist
# >>>  Historical data of NVGN exists but has no trading data
# |||  Historical data of ZGNX doesn't exist
# |||  Historical data of GWPH doesn't exist
# |||  Historical data of SKBI doesn't exist
# |||  Historical data of TGLP doesn't exist
# |||  Historical data of IMNP doesn't exist
# |||  Historical data of GCVRZ doesn't exist
# |||  Historical data of RTRX doesn't exist
# >>>  Historical data of ALIM saved
# >>>  Historical data of INNV saved
# >>>  Historical data of TNXP saved
# >>>  Historical data of NTRR saved
# >>>  Historical data of TXMD saved
# >>>  Historical data of ASMB saved
# >>>  Historical data of ABBV saved
# >>>  Historical data of PRTT saved
# >>>  Historical data of NNVC saved
# >>>  Historical data of BSPM saved
# >>>  Historical data of CPHI saved
# >>>  Historical data of IPXL saved
# >>>  Historical data of HSTC saved
# >>>  Historical data of RMTI saved
# >>>  Historical data of AZN saved
# >>>  Historical data of PVCT saved
# >>>  Historical data of NVS saved
# >>>  Historical data of GSK saved
# >>>  Historical data of LLY saved
# >>>  Historical data of BMY saved
# >>>  Historical data of PFE saved
# >>>  Historical data of JNJ saved
# >>>  Historical data of MRK saved
# All downloads completed !
# |||  Historical data of AKS doesn't exist
# |||  Historical data of SYNL doesn't exist
# |||  Historical data of AAST doesn't exist
# |||  Historical data of CPSL doesn't exist
# |||  Historical data of OSN doesn't exist
# |||  Historical data of MTL doesn't exist
# >>>  Historical data of IGC saved
# >>>  Historical data of TMST saved
# >>>  Historical data of MT saved
# >>>  Historical data of TX saved
# >>>  Historical data of ZEUS saved
# >>>  Historical data of NWPX saved
# >>>  Historical data of SIM saved
# >>>  Historical data of SID saved
# >>>  Historical data of RS saved
# >>>  Historical data of IIIN saved
# >>>  Historical data of PKX saved
# >>>  Historical data of USAP saved
# >>>  Historical data of GGB saved
# >>>  Historical data of ROCK saved
# >>>  Historical data of STLD saved
# >>>  Historical data of SCHN saved
# >>>  Historical data of X saved
# >>>  Historical data of FRD saved
# >>>  Historical data of CMC saved
# >>>  Historical data of WOR saved
# >>>  Historical data of NUE saved
# All downloads completed !
# |||  Historical data of AQXP doesn't exist
# |||  Historical data of FCSC doesn't exist
# |||  Historical data of MDCO doesn't exist
# |||  Historical data of ADMS doesn't exist
# >>>  Historical data of VSAR exists but has no trading data
# >>>  Historical data of PSDV exists but has no trading data
# |||  Historical data of SPHS doesn't exist
# |||  Historical data of MYOS doesn't exist
# |||  Historical data of MNTA doesn't exist
# |||  Historical data of FLXN doesn't exist
# |||  Historical data of AGN doesn't exist
# |||  Historical data of DPLO doesn't exist
# |||  Historical data of TTPH doesn't exist
# >>>  Historical data of MNK saved
# |||  Historical data of MYL doesn't exist
# |||  Historical data of NEOS doesn't exist
# |||  Historical data of AKRX doesn't exist
# >>>  Historical data of AKTX saved
# >>>  Historical data of AGRX saved
# >>>  Historical data of STDY saved
# >>>  Historical data of COLL saved
# >>>  Historical data of CTLT saved
# >>>  Historical data of TRGM saved
# >>>  Historical data of ZYNE saved
# >>>  Historical data of EGRX saved
# >>>  Historical data of SCYX saved
# >>>  Historical data of LPCN saved
# >>>  Historical data of EVOK saved
# >>>  Historical data of KPTI saved
# >>>  Historical data of HZNP saved
# >>>  Historical data of ZTS saved
# >>>  Historical data of PCRX saved
# >>>  Historical data of SUPN saved
# >>>  Historical data of RLMD saved
# >>>  Historical data of NBIX saved
# >>>  Historical data of NATR saved
# >>>  Historical data of CPRX saved
# >>>  Historical data of IRWD saved
# >>>  Historical data of MYRX saved
# >>>  Historical data of GALT saved
# >>>  Historical data of RIGL saved
# >>>  Historical data of JNP saved
# >>>  Historical data of LCI saved
# All downloads completed !
# |||  Historical data of EOPT doesn't exist
# |||  Historical data of REN doesn't exist
# |||  Historical data of COG doesn't exist
# |||  Historical data of PER doesn't exist
# |||  Historical data of CRZO doesn't exist
# |||  Historical data of ATLS doesn't exist
# >>>  Historical data of XCO exists but has no trading data
# |||  Historical data of TPLM doesn't exist
# |||  Historical data of RICE doesn't exist
# >>>  Historical data of CIE exists but has no trading data
# |||  Historical data of BCEI doesn't exist
# |||  Historical data of AREX doesn't exist
# |||  Historical data of DNR doesn't exist
# |||  Historical data of CLR doesn't exist
# |||  Historical data of XEC doesn't exist
# |||  Historical data of CHK-PD doesn't exist
# >>>  Historical data of BXE exists but has no trading data
# |||  Historical data of QEGY doesn't exist
# |||  Historical data of SN doesn't exist
# |||  Historical data of OAS doesn't exist
# |||  Historical data of ROYT doesn't exist
# >>>  Historical data of NDRO exists but has no trading data
# |||  Historical data of SDR doesn't exist
# |||  Historical data of SDT doesn't exist
# >>>  Historical data of SGY exists but has no trading data
# >>>  Historical data of FPP exists but has no trading data
# |||  Historical data of ECR doesn't exist
# |||  Historical data of SARA doesn't exist
# >>>  Historical data of PQ exists but has no trading data
# >>>  Historical data of GST exists but has no trading data
# |||  Historical data of DLOV doesn't exist
# >>>  Historical data of ERN saved
# |||  Historical data of MCEP doesn't exist
# |||  Historical data of VOIL doesn't exist
# |||  Historical data of MCF doesn't exist
# |||  Historical data of ZN doesn't exist
# |||  Historical data of YUMA doesn't exist
# |||  Historical data of APC doesn't exist
# |||  Historical data of LLEX doesn't exist
# >>>  Historical data of CRC saved
# |||  Historical data of PE doesn't exist
# |||  Historical data of CEGX doesn't exist
# >>>  Historical data of EXXI exists but has no trading data
# >>>  Historical data of ISRL saved
# |||  Historical data of LPI doesn't exist
# |||  Historical data of EPE doesn't exist
# |||  Historical data of EMPR doesn't exist
# |||  Historical data of NBL doesn't exist
# |||  Historical data of UPL doesn't exist
# |||  Historical data of JONE doesn't exist
# |||  Historical data of GFOX doesn't exist
# |||  Historical data of TGA doesn't exist
# >>>  Historical data of ENRJ exists but has no trading data
# >>>  Historical data of BMBM exists but has no trading data
# |||  Historical data of TGC doesn't exist
# |||  Historical data of TXJK doesn't exist
# |||  Historical data of WPX doesn't exist
# >>>  Historical data of GPOR saved
# >>>  Historical data of ROSE saved
# >>>  Historical data of LGCY saved
# >>>  Historical data of CHKR saved
# >>>  Historical data of WTXR saved
# >>>  Historical data of MTDR saved
# >>>  Historical data of NSRS saved
# >>>  Historical data of PSSS saved
# >>>  Historical data of BWPC saved
# >>>  Historical data of VNOM saved
# >>>  Historical data of HUSA saved
# >>>  Historical data of ZAZA saved
# >>>  Historical data of DKL saved
# >>>  Historical data of FANG saved
# >>>  Historical data of SFPI saved
# >>>  Historical data of WCYN saved>>>  Historical data of KOS saved
#
# >>>  Historical data of RSRV saved
# >>>  Historical data of GNE saved
# >>>  Historical data of VOC saved
# >>>  Historical data of MVO saved
# >>>  Historical data of BTE saved
# >>>  Historical data of ENLK saved
# >>>  Historical data of ALOD saved
# >>>  Historical data of BBLS saved
# >>>  Historical data of OILY saved
# >>>  Historical data of ECCE saved
# >>>  Historical data of ERHE saved>>>  Historical data of SKPI saved
#
# >>>  Historical data of CRBO saved
# >>>  Historical data of BSM saved
# >>>  Historical data of OAKR saved
# >>>  Historical data of GTE saved
# >>>  Historical data of LOGL saved
# >>>  Historical data of EPM saved
# >>>  Historical data of DBRM saved
# >>>  Historical data of EEQ saved
# >>>  Historical data of CPG saved
# >>>  Historical data of EPD saved
# >>>  Historical data of CPPXF saved
# >>>  Historical data of CPE saved
# >>>  Historical data of SPND saved
# >>>  Historical data of BNXR saved
# >>>  Historical data of AXAS saved
# >>>  Historical data of ESTE saved
# >>>  Historical data of GBR saved
# >>>  Historical data of ENSV saved
# >>>  Historical data of SM saved
# >>>  Historical data of ROYL saved
# >>>  Historical data of PXD saved
# >>>  Historical data of CNX saved
# >>>  Historical data of PHX saved
# >>>  Historical data of ALTX saved
# >>>  Historical data of EGY saved
# >>>  Historical data of PNRG saved
# >>>  Historical data of EOG saved
# >>>  Historical data of NFX saved
# >>>  Historical data of CNQ saved
# >>>  Historical data of MXC saved
# >>>  Historical data of ESSE saved
# >>>  Historical data of DVN saved
# >>>  Historical data of PDCE saved
# >>>  Historical data of BDCO saved
# >>>  Historical data of SJT saved
# >>>  Historical data of CRK saved
# >>>  Historical data of USEG saved
# >>>  Historical data of PBT saved
# >>>  Historical data of MUR saved
# >>>  Historical data of RRC saved
# >>>  Historical data of SU saved
# >>>  Historical data of APA saved
# >>>  Historical data of SWN saved
# >>>  Historical data of BRN saved
# >>>  Historical data of COP saved
# >>>  Historical data of OXY saved
# >>>  Historical data of NFG saved
# >>>  Historical data of EQT saved
# >>>  Historical data of HES saved
# >>>  Historical data of EGN saved
# >>>  Historical data of MRO saved
# All downloads completed !
# |||  Historical data of IAIC doesn't exist|||  Historical data of AVRN doesn't exist
#
# >>>  Historical data of BKFS exists but has no trading data
# |||  Historical data of SFOR doesn't exist
# |||  Historical data of CTXS doesn't exist
# |||  Historical data of MOST doesn't exist
# ...
# |||  Historical data of TLK doesn't exist
# |||  Historical data of ORBC doesn't exist
# |||  Historical data of IGLD doesn't exist
# |||  Historical data of CABO doesn't exist
# |||  Historical data of SBAC doesn't exist
# |||  Historical data of WPCS doesn't exist
# |||  Historical data of EGHT doesn't exist
# |||  Historical data of HCOM doesn't exist
# |||  Historical data of DCM doesn't exist
# |||  Historical data of VLTC doesn't exist
# |||  Historical data of STRP doesn't exist
# All downloads completed !
# |||  Historical data of ESGI doesn't exist|||  Historical data of PICO doesn't exist
#
# |||  Historical data of DLYT doesn't exist
# |||  Historical data of ANDAU doesn't exist
# |||  Historical data of CODI doesn't exist
# |||  Historical data of EAGL doesn't exist
# |||  Historical data of RJDG doesn't exist
# |||  Historical data of AAPC doesn't exist
# |||  Historical data of VCMG doesn't exist
# |||  Historical data of ENVV doesn't exist
# |||  Historical data of HPCQ doesn't exist
# |||  Historical data of AZRH doesn't exist
# |||  Historical data of FCIC doesn't exist
# |||  Historical data of REX doesn't exist
# |||  Historical data of BLVDW doesn't exist
# |||  Historical data of SPLY doesn't exist
# |||  Historical data of RIHT doesn't exist
# |||  Historical data of ALLM doesn't exist
# |||  Historical data of HRG doesn't exist
# |||  Historical data of UTMR doesn't exist
# |||  Historical data of AGFS doesn't exist
# |||  Historical data of DIMN doesn't exist
# |||  Historical data of PSTO doesn't exist
# |||  Historical data of ELRN doesn't exist
# |||  Historical data of PTPF doesn't exist
# |||  Historical data of BMMCF doesn't exist
# |||  Historical data of GSPE doesn't exist
# |||  Historical data of ZMDC doesn't exist
# |||  Historical data of DPSM doesn't exist
# |||  Historical data of IFAN doesn't exist
# |||  Historical data of SPNI doesn't exist
# |||  Historical data of BTFL doesn't exist
# |||  Historical data of PWRV doesn't exist
# |||  Historical data of MDRM doesn't exist
# |||  Historical data of SEB doesn't exist
# |||  Historical data of MXMG doesn't exist
# |||  Historical data of GEZC doesn't exist
# |||  Historical data of IEP doesn't exist
# |||  Historical data of TBLZ doesn't exist
# |||  Historical data of SPLP doesn't exist
# |||  Historical data of CLSH doesn't exist
# |||  Historical data of OROE doesn't exist
# |||  Historical data of BHAC doesn't exist
# |||  Historical data of HKBT doesn't exist
# |||  Historical data of GLBD doesn't exist
# |||  Historical data of AXIM doesn't exist
# |||  Historical data of HOMR doesn't exist
# |||  Historical data of HISP doesn't exist
# |||  Historical data of PGEC doesn't exist
# |||  Historical data of TCKF doesn't exist
# |||  Historical data of CEXE doesn't exist
# |||  Historical data of DALP doesn't exist
# |||  Historical data of SLOT doesn't exist
# |||  Historical data of OMVS doesn't exist
# |||  Historical data of PGSC doesn't exist
# |||  Historical data of CMXC doesn't exist
# |||  Historical data of RDGA doesn't exist
# |||  Historical data of OPBL doesn't exist
# |||  Historical data of MAGAA doesn't exist
# |||  Historical data of HCACU doesn't exist
# |||  Historical data of GSPH doesn't exist
# |||  Historical data of SHGT doesn't exist
# |||  Historical data of PRLX doesn't exist
# |||  Historical data of PGRD doesn't exist
# |||  Historical data of GTSO doesn't exist
# |||  Historical data of AFAN doesn't exist
# |||  Historical data of ZENO doesn't exist
# |||  Historical data of MKBY doesn't exist
# |||  Historical data of YPPN doesn't exist
# |||  Historical data of CAMG doesn't exist
# |||  Historical data of ALAD doesn't exist
# |||  Historical data of BRKK doesn't exist
# |||  Historical data of CNWHF doesn't exist
# |||  Historical data of HMPQ doesn't exist
# |||  Historical data of HBPE doesn't exist
# |||  Historical data of SGNI doesn't exist
# |||  Historical data of DLDG doesn't exist
# |||  Historical data of LNGB doesn't exist
# |||  Historical data of HZNM doesn't exist
# |||  Historical data of CETH doesn't exist
# |||  Historical data of USBL doesn't exist
# |||  Historical data of MOBO doesn't exist
# |||  Historical data of FNAM doesn't exist
# |||  Historical data of SGBX doesn't exist
# |||  Historical data of AEXE doesn't exist
# |||  Historical data of GPLA doesn't exist
# |||  Historical data of TXSO doesn't exist
# |||  Historical data of RSSV doesn't exist
# |||  Historical data of LPTC doesn't exist
# |||  Historical data of CYNK doesn't exist
# |||  Historical data of CRPT doesn't exist
# |||  Historical data of TSTS doesn't exist
# |||  Historical data of GPNE doesn't exist
# |||  Historical data of MDDD doesn't exist
# |||  Historical data of TCNT doesn't exist
# |||  Historical data of MNAI doesn't exist
# |||  Historical data of MCPI doesn't exist
# |||  Historical data of SGMZ doesn't exist
# All downloads completed !
# |||  Historical data of CACQ doesn't exist|||  Historical data of VAC doesn't exist
# |||  Historical data of LVS doesn't exist
# |||  Historical data of GDEN doesn't exist
# |||  Historical data of NYNY doesn't exist
# |||  Historical data of WYNN doesn't exist
# |||  Historical data of CZR doesn't exist
# |||  Historical data of MCRI doesn't exist
#
# |||  Historical data of TBTC doesn't exist
# |||  Historical data of PENN doesn't exist
# |||  Historical data of BYD doesn't exist
# |||  Historical data of CNTY doesn't exist
# |||  Historical data of CCL doesn't exist
# |||  Historical data of GBCS doesn't exist
# |||  Historical data of LQ doesn't exist
# |||  Historical data of FLL doesn't exist
# |||  Historical data of MGM doesn't exist
# |||  Historical data of UWN doesn't exist
# |||  Historical data of RCL doesn't exist
# |||  Historical data of PNK doesn't exist
# |||  Historical data of MTN doesn't exist
# |||  Historical data of ERI doesn't exist
# All downloads completed !
# |||  Historical data of ASCCF doesn't exist
# |||  Historical data of MATW doesn't exist
# |||  Historical data of BFAM doesn't exist
# |||  Historical data of HRB doesn't exist
# |||  Historical data of CCGI doesn't exist
# |||  Historical data of IPOW doesn't exist
# |||  Historical data of MSLP doesn't exist
# |||  Historical data of NTRI doesn't exist
# |||  Historical data of CSV doesn't exist
# |||  Historical data of SCI doesn't exist
# |||  Historical data of RGS doesn't exist
# |||  Historical data of CBDS doesn't exist
# |||  Historical data of WOOF doesn't exist
# |||  Historical data of ASCC doesn't exist
# |||  Historical data of TAX doesn't exist
# |||  Historical data of STON doesn't exist
# |||  Historical data of WTW doesn't exist
# |||  Historical data of SFLY doesn't exist
# |||  Historical data of ONVC doesn't exist
# All downloads completed !
# |||  Historical data of POPE doesn't exist
# |||  Historical data of DEL doesn't exist
# |||  Historical data of BCC doesn't exist
# |||  Historical data of RYN doesn't exist
# |||  Historical data of PCH doesn't exist
# |||  Historical data of UFPI doesn't exist
# |||  Historical data of EVA doesn't exist
# |||  Historical data of WY doesn't exist
# |||  Historical data of CTT doesn't exist
# |||  Historical data of PATK doesn't exist
# |||  Historical data of JCTCF doesn't exist
# All downloads completed !
# |||  Historical data of OME doesn't exist
# |||  Historical data of JBSS doesn't exist
# |||  Historical data of ALN doesn't exist
# |||  Historical data of GIS doesn't exist
# |||  Historical data of FARM doesn't exist
# |||  Historical data of OPCO doesn't exist
# |||  Historical data of FLO doesn't exist
# |||  Historical data of CMFO doesn't exist
# |||  Historical data of CPB doesn't exist
# |||  Historical data of JVA doesn't exist
# |||  Historical data of SENEB doesn't exist
# |||  Historical data of SNAK doesn't exist
# |||  Historical data of K doesn't exist
# |||  Historical data of SJM doesn't exist
# |||  Historical data of LNCE doesn't exist
# |||  Historical data of BABB doesn't exist
# |||  Historical data of SENEB doesn't exist
# |||  Historical data of INGR doesn't exist
# |||  Historical data of CAG doesn't exist
# |||  Historical data of FVRG doesn't exist
# |||  Historical data of JJSF doesn't exist
# |||  Historical data of THS doesn't exist
# |||  Historical data of BGS doesn't exist
# |||  Historical data of MKC doesn't exist
# All downloads completed !
# |||  Historical data of PRMW doesn't exist
# |||  Historical data of BRFH doesn't exist
# |||  Historical data of FIZZ doesn't exist
# |||  Historical data of COKE doesn't exist
# |||  Historical data of AKO-A doesn't exist
# |||  Historical data of SODA doesn't exist
# |||  Historical data of AKO-A doesn't exist
# |||  Historical data of KRED doesn't exist
# |||  Historical data of CCE doesn't exist
# |||  Historical data of UPNT doesn't exist
# |||  Historical data of MNST doesn't exist
# |||  Historical data of CRVP doesn't exist
# |||  Historical data of FBEC doesn't exist
# |||  Historical data of SENZ doesn't exist
# |||  Historical data of JSDA doesn't exist
# |||  Historical data of KOF doesn't exist
# |||  Historical data of WTER doesn't exist
# |||  Historical data of DPS doesn't exist
# |||  Historical data of CELH doesn't exist
# |||  Historical data of MOJO doesn't exist
# |||  Historical data of REED doesn't exist
# |||  Historical data of KO doesn't exist
# |||  Historical data of LBIX doesn't exist
# |||  Historical data of PEP doesn't exist
# |||  Historical data of COT doesn't exist
# |||  Historical data of OMGB doesn't exist
# All downloads completed !
# |||  Historical data of NXST doesn't exist
# |||  Historical data of EVC doesn't exist
# |||  Historical data of LBRDA doesn't exist
# |||  Historical data of SBGI doesn't exist
# |||  Historical data of REBL doesn't exist
# |||  Historical data of TGNA doesn't exist
# |||  Historical data of SIGN doesn't exist
# |||  Historical data of NWSA doesn't exist
# |||  Historical data of SNI doesn't exist
# |||  Historical data of ADGL doesn't exist
# |||  Historical data of GTN-A doesn't exist
# |||  Historical data of SSP doesn't exist
# |||  Historical data of TRCO doesn't exist
# |||  Historical data of RLJE doesn't exist
# |||  Historical data of GTN-A doesn't exist
# |||  Historical data of TV doesn't exist
# |||  Historical data of CETV doesn't exist
# |||  Historical data of NTN doesn't exist
# All downloads completed !
# |||  Historical data of TRK doesn't exist
# |||  Historical data of PLNT doesn't exist
# |||  Historical data of CLUB doesn't exist
# |||  Historical data of DVD doesn't exist
# |||  Historical data of MYCC doesn't exist
# |||  Historical data of SEAS doesn't exist
# |||  Historical data of ATOC doesn't exist
# |||  Historical data of GNTP doesn't exist
# |||  Historical data of ISCA doesn't exist
# |||  Historical data of SKIS doesn't exist
# |||  Historical data of AASP doesn't exist
# |||  Historical data of LFL doesn't exist
# |||  Historical data of MANU doesn't exist
# All downloads completed !
# |||  Historical data of SXI doesn't exist
# |||  Historical data of B doesn't exist
# |||  Historical data of WTS doesn't exist
# |||  Historical data of CCF doesn't exist
# |||  Historical data of BHTG doesn't exist
# |||  Historical data of OFLX doesn't exist
# |||  Historical data of ABKI doesn't exist
# |||  Historical data of NFEC doesn't exist
# |||  Historical data of SNHY doesn't exist
# |||  Historical data of BGC doesn't exist
# |||  Historical data of CIR doesn't exist
# |||  Historical data of PNR doesn't exist
# |||  Historical data of MWA doesn't exist
# |||  Historical data of NPO doesn't exist
# |||  Historical data of PH doesn't exist
# |||  Historical data of ASPW doesn't exist
# |||  Historical data of CETX doesn't exist
# |||  Historical data of HEAT doesn't exist
# |||  Historical data of HNH doesn't exist
# |||  Historical data of TRS doesn't exist
# All downloads completed !
# |||  Historical data of BWMG doesn't exist
# |||  Historical data of MBUU doesn't exist
# |||  Historical data of MOV doesn't exist
# |||  Historical data of TOUR doesn't exist
# |||  Historical data of TRPO doesn't exist
# |||  Historical data of LTRPA doesn't exist
# |||  Historical data of GLXZ doesn't exist
# |||  Historical data of EPGG doesn't exist
# |||  Historical data of BC doesn't exist
# |||  Historical data of LIND doesn't exist
# |||  Historical data of TVPT doesn't exist
# All downloads completed !
# |||  Historical data of ICON doesn't exist
# |||  Historical data of COH doesn't exist
# |||  Historical data of RCKY doesn't exist
# |||  Historical data of CROX doesn't exist
# |||  Historical data of SHOO doesn't exist
# |||  Historical data of DECK doesn't exist
# |||  Historical data of WWW doesn't exist
# |||  Historical data of FL doesn't exist
# |||  Historical data of FORD doesn't exist
# |||  Historical data of TLF doesn't exist
# |||  Historical data of VRA doesn't exist
# |||  Historical data of WEYS doesn't exist
# |||  Historical data of CAL doesn't exist
# |||  Historical data of FOSL doesn't exist
# |||  Historical data of SKX doesn't exist
# |||  Historical data of NKE doesn't exist
# All downloads completed !
# |||  Historical data of IEC doesn't exist
# |||  Historical data of CLS doesn't exist
# |||  Historical data of JBL doesn't exist
# |||  Historical data of PLXS doesn't exist
# |||  Historical data of FLEX doesn't exist
# |||  Historical data of ELTK doesn't exist
# |||  Historical data of TTMI doesn't exist
# |||  Historical data of SMTX doesn't exist
# |||  Historical data of KBAL doesn't exist
# |||  Historical data of SGMA doesn't exist
# |||  Historical data of BHE doesn't exist
# All downloads completed !
# |||  Historical data of COST doesn't exist
# |||  Historical data of BIG doesn't exist
# |||  Historical data of TGT doesn't exist
# |||  Historical data of PSMT doesn't exist
# |||  Historical data of DLTR doesn't exist
# |||  Historical data of FRED doesn't exist
# |||  Historical data of OLLI doesn't exist
# |||  Historical data of WMT doesn't exist
# |||  Historical data of TUES doesn't exist
# |||  Historical data of DG doesn't exist
# |||  Historical data of BURL doesn't exist
# All downloads completed !
# |||  Historical data of NGVC doesn't exist
# |||  Historical data of WFM doesn't exist
# |||  Historical data of KR doesn't exist
# |||  Historical data of SFS doesn't exist
# |||  Historical data of QKLS doesn't exist
# |||  Historical data of SFM doesn't exist
# |||  Historical data of SVU doesn't exist
# |||  Historical data of CASY doesn't exist
# |||  Historical data of CBD doesn't exist
# |||  Historical data of IMKTA doesn't exist
# |||  Historical data of VLGEA doesn't exist
# |||  Historical data of WMK doesn't exist
# All downloads completed !
# |||  Historical data of DISH doesn't exist|||  Historical data of HMTV doesn't exist
# |||  Historical data of VDTH doesn't exist
#
# |||  Historical data of DISCA doesn't exist
# |||  Historical data of LILA doesn't exist
# |||  Historical data of SJR doesn't exist
# |||  Historical data of NFLX doesn't exist
# |||  Historical data of LBTYA doesn't exist
# |||  Historical data of IMDC doesn't exist
# |||  Historical data of ROVI doesn't exist
# |||  Historical data of CHTR doesn't exist
# All downloads completed !
# |||  Historical data of MNR doesn't exist
# |||  Historical data of DCT doesn't exist
# |||  Historical data of DRE doesn't exist
# |||  Historical data of REXR doesn't exist
# |||  Historical data of CMCT doesn't exist
# |||  Historical data of STAG doesn't exist
# |||  Historical data of JCAP doesn't exist
# |||  Historical data of PLD doesn't exist
# |||  Historical data of QTS doesn't exist
# |||  Historical data of CUBE doesn't exist
# |||  Historical data of PSA-PY doesn't exist
# |||  Historical data of TRNO doesn't exist
# |||  Historical data of EGP doesn't exist
# |||  Historical data of EXR doesn't exist
# |||  Historical data of FR doesn't exist
# All downloads completed !
# |||  Historical data of IGEN doesn't exist
# |||  Historical data of WSCO doesn't exist
# |||  Historical data of DLTZ doesn't exist
# |||  Historical data of SYTE doesn't exist
# |||  Historical data of TRUE doesn't exist
# |||  Historical data of FULO doesn't exist
# |||  Historical data of GAWK doesn't exist
# |||  Historical data of ACAN doesn't exist
# |||  Historical data of LOV doesn't exist
# |||  Historical data of SHSP doesn't exist
# |||  Historical data of WESC doesn't exist
# |||  Historical data of HLTK doesn't exist
# |||  Historical data of CRMZ doesn't exist
# |||  Historical data of SIFY doesn't exist
# All downloads completed !

# %% [markdown]
# ## Remove empty with less than 10 companies

# %%
import shutil
data_path = '../historic_data/'
categories = listdir(data_path)
for i in categories:
    if len(listdir(data_path+i))<10:
        shutil.rmtree(data_path+i)

# %% [markdown]
# ## So like this you can update data everyday by yourself
# <br/>
#
# ### Source :
# * **[Stack Overflow](https://stackoverflow.com/)**
# * **[Yahoo Finance](https://in.finance.yahoo.com/)**
# * **[Stack Exchange](https://stackexchange.com/)**
# * **[Python](https://www.python.org/)**
# * **[Geeks for Geeks](https://www.geeksforgeeks.org/)**
